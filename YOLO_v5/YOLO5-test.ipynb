# %%
# YOLO v.5 in test regime, source: @ultralytics.

# %%
import torch
from IPython.display import Image  # for displaying images

# %%
print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 1.5.1 _CudaDeviceProperties(name='GeForce GTX 1060', major=6, minor=1, total_memory=6144MB, multi_processor_count=10)

# %%
# Running in the script mode
# inputs: image, video, dir with files, webcam, ip-cam 

# !python detect.py --source ./inference/videos/
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', fourcc='mp4v', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='./inference/videos/', view_img=False, weights='weights/yolov5s.pt')
# Using CPU
#
# video 1/2 (1/197) inference\videos\test2.MP4: 384x640 1 persons, 6 cars, Done. (0.485s)
# video 1/2 (2/197) inference\videos\test2.MP4: 384x640 1 persons, 6 cars, Done. (0.450s)
# video 1/2 (3/197) inference\videos\test2.MP4: 384x640 2 persons, 6 cars, Done. (0.438s)
# video 1/2 (4/197) inference\videos\test2.MP4: 384x640 1 persons, 7 cars, Done. (0.367s)
# video 1/2 (5/197) inference\videos\test2.MP4: 384x640 1 persons, 7 cars, Done. (0.404s)
# video 1/2 (6/197) inference\videos\test2.MP4: 384x640 7 cars, Done. (0.434s)
# video 1/2 (7/197) inference\videos\test2.MP4: 384x640 1 persons, 7 cars, Done. (0.369s)
# video 1/2 (8/197) inference\videos\test2.MP4: 384x640 7 cars, Done. (0.409s)
# ...

# %%
Image(filename='./inference/output/street_car_1.jpg', width=600)
